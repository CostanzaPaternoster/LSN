# %% [markdown]
# # MD NVE - Fase gassosa
# ### $T=1.2$, $\rho=0.05$

# %% [markdown]
# ## Equilibrazione
# Di seguito si mostrano i seguenti grafici,in cui le quantità sono riportate in unità ridotte:
#
# 1. temperatura istantanea in funzione del tempo di integrazione per tutta la durata della simulazione ($10^4 passi$). La temperatura iniziale viene impostata uguale a quella target $T^*$ e il sistema viene fatto evolvere senza riscalamenti;
# 2. temperatura istantanea in funzione del tempo di integrazione durante l'equilibrazione forzata. Il numero di passi tra un riscalamento e il successivo è stato scelto osservando l'andamento del grafico 1. Gli ultimi 1000 passi corrispondono ai $10^4$ passi di simulazione, durante la quale la temperatura è stata misurata ogni 10 intervalli di tempo.
#
# Configurazione di partenza: configurazione finale (opportunamente riscalata) della simulazione del liquido.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal as d

# %%
# Equilibrazione: T vs t
T_inst = np.loadtxt("Gas/Instant/instant_temp0.txt", usecols=(0), unpack = 'true')
T_eq = np.loadtxt("Gas/Instant/instant_temp.txt", usecols=(0), unpack = 'true')

L = len(T_inst)
t1 = np.arange(L)
L = len(T_eq)
t2 = np.arange(L)
T_gas = 1.2*np.ones(L)


f = plt.figure(figsize=(13,4))

f.add_subplot(1,2,1)
plt.plot(t1,T_inst)
plt.xlabel('time step')
plt.ylabel('$T$')
plt.ylim(1.15,1.75)
plt.title('Temperatura istantanea vs tempo',size=13)
plt.grid()

f.add_subplot(1,2,2)
plt.plot(t2,T_eq)
plt.plot(t2,T_gas,label='temperatura target',color='r')
plt.xlabel('time step')
plt.ylabel('$T$')
plt.title('Temperatura istantanea vs tempo in fase di equilibrazione',size=13)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# Equilibrazione a $T=1.2$ con 4 ripetizioni di 2000 passi.
#
# Sono due le osservazioni da fare:
# - dal grafico a sx si evince che il gas necessita di almeno 2000 passi di integrazione per raggiungere l'equilibrio, un tempo maggiore rispetto a quell richiesto dal solido e dal liquido.
# - la temperatura aumenta in modo evidente durante i primi 2000 passi, a differenza di quanto accade per il solido e il liquido.
#
# Il gas è caratterizzato da una densità molto minore rispetto a quello del liquido o del solido, il che significa che le particelle che lo compongono sono poste a distanza maggiore tra di loro (in una configurazione molto diversa da quella che minimizza il potenziale) ed interagiscono, quindi, in modo $\textit debolmente$ $\textit attrattivo$. Esse si muovono verso configurazioni ad energia potenziale minore (cioè energia cinetica maggiore - per la conservazione dell'energia totale) in maniera lenta.
#
# A causa delle sue fluttuazioni non è stato semplice capire se il gas avesse raggiunto l'equilibrio termodinamico alla temperatura desiderata.
#
# Il time-step è stato mantenuto a $0.0005$ per tutte e tre le fasi termodinamiche, ma nel caso del gas un'idea potrebbe essere quella di incrementarlo a $0.001$.

# %% [markdown]
# ## Simulazione

# %% [markdown]
# Dopo aver equilibrato il sistema alla temperatura $T^*=1.2$ è stata effettuata la simulazione per $10^4$ passi - con passo di $0.0005$ - divisi in $100$ blocchi. Di seguito sono riportati i grafici con gli andamenti medi di energia potenziale, energia cinetica, energia totale (per particella), temperatura e pressione in funzione del tempo di integrazione. Le varie grandezze sono state riscalate utilizzando i valori di $\sigma$, $\epsilon$ e $m$ relativi all'Argon e al Krypton (presentati nel jupyter "Introduzione.ipynb") e presentate in unità del SI.

# %%
k_B = 1.38065*10**(-23) # J/K
amu = 1.661*10**(-27) # kg/amu

# ARGON: unità di misura SI
sigma_A = 0.34*10**(-9) # m
epsilon_A = 120*k_B # J
T_A = 120 # K
m_A = 39.948*amu # kg
tau_A = sigma_A*m_A**(1/2)*epsilon_A**(-1/2) # s
p_A = epsilon_A*sigma_A**(-3) # Pa

# KRYPTON: unità SI
sigma_K = 0.364*10**(-9) # m
epsilon_K = 164*k_B # J
T_K = 164 # K
m_K = 83.798*amu # kg
tau_K = sigma_K*m_K**(1/2)*epsilon_K**(-1/2) # s
p_K = epsilon_K*sigma_K**(-3) # Pa

# %% [markdown]
# ### Energia potenziale media per particella

# %%
# Energia potenziale media per particella vs t: Argon e Krypton
t,U,err_U = np.loadtxt("Gas/Average/epot.txt", usecols=(0,2,3), unpack = 'true')
N = len(t)

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
plt.errorbar(t*tau_A*100,U*epsilon_A,err_U*epsilon_A)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia potenziale [J]',size=13)
plt.title('ARGON',size=15)
plt.grid()

f.add_subplot(1,2,2)
plt.errorbar(t*tau_K*100,U*epsilon_K,err_U*epsilon_K)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia potenziale [J]',size=13)
plt.title('KRYPTON',size=15)
plt.grid()

plt.show()

print('Energia potenziale media per particella (unità ridotte):',round(U[N-1],3),'+/-',round(err_U[N-1],3))
print('Energia potenziale media per particella (Argon):',round(d(U[N-1]*epsilon_A),24),'+/-',round(d(err_U[N-1]*epsilon_A),24),'J')
print('Energia potenziale media per particella (Krypton):',round(d(U[N-1]*epsilon_K),23),'+/-',round(d(err_U[N-1]*epsilon_K),23),'J')
# Out:
# Energia potenziale media per particella (unità ridotte): -0.381 +/- 0.002
# Energia potenziale media per particella (Argon): -6.31E-22 +/- 4E-24 J
# Energia potenziale media per particella (Krypton): -8.6E-22 +/- 1E-23 J

# %% [markdown]
# ### Energia cinetica media per particella

# %%
# Energia cinetica media per particella vs t: Argon e Krypton
t,K,err_K = np.loadtxt("Gas/Average/ekin.txt", usecols=(0,2,3), unpack = 'true')
N = len(t)

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
plt.errorbar(t*tau_A*100,K*epsilon_A,err_K*epsilon_A)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia cinetica [J]',size=13)
plt.title('ARGON',size=15)
plt.grid()

f.add_subplot(1,2,2)
plt.errorbar(t*tau_K*100,K*epsilon_K,err_K*epsilon_K)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia cinetica [J]',size=13)
plt.title('KRYPTON',size=15)
plt.grid()

plt.show()

print('Energia cinetica media per particella (unità ridotte):',round(K[N-1],3),'+/-',round(err_K[N-1],3))
print('Energia cinetica media per particella (Argon):',round(d(K[N-1]*epsilon_A),24),'+/-',round(d(err_K[N-1]*epsilon_A),24),'J')
print('Energia cinetica media per particella (Krypton):',round(d(K[N-1]*epsilon_K),23),'+/-',round(d(err_K[N-1]*epsilon_K),23),'J')
# Out:
# Energia cinetica media per particella (unità ridotte): 1.825 +/- 0.002
# Energia cinetica media per particella (Argon): 3.024E-21 +/- 4E-24 J
# Energia cinetica media per particella (Krypton): 4.13E-21 +/- 1E-23 J

# %% [markdown]
# ### Energia totale media per particella

# %%
# Energia totale media per particella vs t: Argon e Krypton
t,E,err_E = np.loadtxt("Gas/Average/etot.txt", usecols=(0,2,3), unpack = 'true')
N = len(t)

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
plt.errorbar(t*tau_A*100,E*epsilon_A,err_E*epsilon_A)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia totale [J]',size=13)
plt.title('ARGON',size=15)
plt.grid()

f.add_subplot(1,2,2)
plt.errorbar(t*tau_K*100,E*epsilon_K,err_E*epsilon_K)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('energia totale [J]',size=13)
plt.title('KRYPTON',size=15)
plt.grid()

plt.show()

print('Energia totale media per particella (unità ridotte):',round(E[N-1],5),'+/-',round(err_E[N-1],5))
print('Energia totale media per particella (Argon):',round(d(E[N-1]*epsilon_A),26),'+/-',round(d(err_E[N-1]*epsilon_A),26),'J')
print('Energia totale media per particella (Krypton):',round(d(E[N-1]*epsilon_K),25),'+/-',round(d(err_E[N-1]*epsilon_K),25),'J')
# Out:
# Energia totale media per particella (unità ridotte): 1.44424 +/- 3e-05
# Energia totale media per particella (Argon): 2.39279E-21 +/- 4E-26 J
# Energia totale media per particella (Krypton): 3.2701E-21 +/- 1E-25 J

# %% [markdown]
# ### Temperatura

# %%
# Temperatura vs t: Argon e Krypton
t,T,err_T = np.loadtxt("Gas/Average/temp.txt", usecols=(0,2,3), unpack = 'true')
N = len(t)

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
plt.errorbar(t*tau_A*100,T*T_A,err_T*T_A)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('temperatura [K]',size=13)
plt.title('ARGON',size=15)
plt.grid()

f.add_subplot(1,2,2)
plt.errorbar(t*tau_K*100,T*T_K,err_T*T_K)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('temperatura [K]',size=13)
plt.title('KRYPTON',size=15)
plt.grid()

plt.show()

print('Temperatura (unità ridotte):',round(T[N-1],3),'+/-',round(err_T[N-1],3))
print('Temperatura (Argon):',round(d(T[N-1]*T_A),1),'+/-',round(d(err_T[N-1]*T_A),1),'K')
print('Temperatura (Krypton):',round(d(T[N-1]*T_K),1),'+/-',round(d(err_T[N-1]*T_K),1),'K')
# Out:
# Temperatura (unità ridotte): 1.217 +/- 0.002
# Temperatura (Argon): 146.0 +/- 0.2 K
# Temperatura (Krypton): 199.6 +/- 0.3 K

# %% [markdown]
# ### Pressione

# %%
# Pressione vs t: Argon e Krypton
t,P,err_P = np.loadtxt("Gas/Average/pres.txt", usecols=(0,2,3), unpack = 'true')
N = len(t)

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
plt.errorbar(t*tau_A*100,P*p_A,err_P*p_A)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('pressione [Pa]',size=13)
plt.title('ARGON',size=15)
plt.grid()

f.add_subplot(1,2,2)
plt.errorbar(t*tau_K*100,P*p_K,err_P*p_K)
plt.xlabel('tempo [s]',size=13)
plt.ylabel('pressione [Pa]',size=13)
plt.title('KRYPTON',size=15)
plt.grid()

plt.show()

print('Pressione (unità ridotte):',round(P[N-1],4),'+/-',round(err_P[N-1],4))
print('Pressione (Argon):',round(d(P[N-1]*p_A),0),'+/-',round(d(err_P[N-1]*p_A),0),'Pa')
print('Pressione (Krypton):',round(d(P[N-1]*p_K),0),'+/-',round(d(err_P[N-1]*p_K),0),'Pa')
# Out:
# Pressione (unità ridotte): 0.0514 +/- 0.0006
# Pressione (Argon): 2166097 +/- 24034 Pa
# Pressione (Krypton): 2412533 +/- 26768 Pa

# %% [markdown]
# Infine, plottiamo due grafici dell'energia potenziale, dell'energia cinetica e dell'energia totale istantanee in funzione del tempo (unità naturali) per mostrare come le fluttuazioni dell'energia cinetica e potenziale siano apprezzabili rispetto a quelle dell'energia totale, che rimane costante durante l'intera durata della simulazione. Nel grafico a dx le energie sono state traslate del loro valor medio per poter essere confrontate.

# %%
U_insta = np.loadtxt('Gas/Instant/instant_epot.txt',usecols=(0), unpack = 'true')
K_insta = np.loadtxt('Gas/Instant/instant_ekin.txt',usecols=(0), unpack = 'true')
E_insta = np.loadtxt('Gas/Instant/instant_etot.txt',usecols=(0), unpack = 'true')

L = len(U_insta)
t = np.arange(L)

f = plt.figure(figsize=(13,4))
f.add_subplot(1,2,1)
plt.plot(t*10,U_insta,label='energia potenziale')
plt.plot(t*10,K_insta,label='energia cinetica')
plt.plot(t*10,E_insta,label='energia totale')
plt.xlabel('tempo')
plt.ylabel('energia')
plt.title('Energie istantanee a confronto',size=15)
plt.legend()
plt.grid()

f.add_subplot(1,2,2)
plt.plot(t*10,U_insta-U[N-1],label='energia potenziale')
plt.plot(t*10,K_insta-K[N-1],label='energia cinetica')
plt.plot(t*10,E_insta-E[N-1],label='energia totale')
plt.xlabel('tempo')
plt.ylabel('energia')
plt.title('Energie istantanee a confronto (traslate)',size=15)
plt.ylim(-0.1,0.1)
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# Dagli andamenti delle energie istantanee riportati nel grafico a dx si possono osservare due tipi di fluttuazioni, caratterizzate da scale temporali diverse. Le fluttuazioni con periodo dell'ordine ~ $10^2$ passi temporali, che sono simili a quelle presenti nel solido e nel liquido, e fluttuazioni con periodo maggiore - di diverse migliaia di passi. Sono quest'ultime correlazioni a rendere particolarmente difficoltosa l'equilibrazione del gas.
